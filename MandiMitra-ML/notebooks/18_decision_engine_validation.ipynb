# %% [markdown]
# # Step 18: Decision Engine Validation
#
# Verify that the recommendation engine produces logically different outcomes for diverse scenarios and handles edge-cases robustly.

# %%
import sys
from pathlib import Path
import pandas as pd
BASE_DIR = Path('..').resolve()
if str(BASE_DIR) not in sys.path: sys.path.insert(0, str(BASE_DIR))

from src.decision_engine_validation import run_validation
run_validation()
# Out:
# MANDIMITRA DECISION ENGINE VALIDATION
#
# ==================================================
# Scenario: 1. Insufficient History (Fallback test)
# Current price: 2500.0
# Forecast price: 2500.0
# Expected percentage change: 0.0%
# Uncertainty: MEDIUM (Regime: UNKNOWN)
# Market comparison: Best = Test Mandi @ ₹NOT_AVAILABLE net
# Final recommendation: SELL TODAY
# Reason: Price is expected to remain approximately stable (change of +0.0%, within the ±2.7% uncertainty band). Your current mandi (Test Mandi) offers the best available net price. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Fewer than 3 recent prices provided; regime detection may be unreliable.
# Warnings: ['Fewer than 3 recent prices provided; regime detection may be unreliable.']
#
# ==================================================
# Scenario: 2. Mock Data Isolation
# Current price: 2500.0
# Forecast price: 2500.0
# Expected percentage change: 0.0%
# Uncertainty: MEDIUM (Regime: LOW_VOLATILITY)
# Market comparison: Best = [TEST_MOCK] Nearby A @ ₹2990.0 net
# Final recommendation: SELL TODAY
# Reason: Price is expected to remain approximately stable (change of +0.0%, within the ±2.7% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi '[TEST_MOCK] Nearby A' offers a higher estimated net price of ₹2990/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at [TEST_MOCK] Nearby A.
# Warnings: ['Better net price available at [TEST_MOCK] Nearby A.']
#
# ==================================================
# Scenario: A. Strong expected price increase
# Current price: 3000.0
# Forecast price: 3400.0
# Expected percentage change: 13.33%
# Uncertainty: HIGH (Regime: LOW_VOLATILITY)
# Market comparison: Best = Test Mandi @ ₹NOT_AVAILABLE net
# Final recommendation: WAIT
# Reason: Price is expected to rise by approximately ₹400/quintal (13.3%) over the next ~3 market observations. The expected price increase (13.3%) is 16.0× larger than the model's historical forecast uncertainty (threshold ±0.8%), suggesting a meaningful signal. Market conditions are stable, supporting more reliable forecasts. Your current mandi (Test Mandi) offers the best available net price. Recommendation: Consider waiting for a potentially better price, though market conditions can change.
#
# ==================================================
# Scenario: B. Strong expected price decrease
# Current price: 3400.0
# Forecast price: 3000.0
# Expected percentage change: -11.76%
# Uncertainty: HIGH (Regime: LOW_VOLATILITY)
# Market comparison: Best = Test Mandi @ ₹NOT_AVAILABLE net
# Final recommendation: SELL TODAY
# Reason: Price is expected to fall by approximately ₹400/quintal (11.8%) over the next ~3 market observations. Market conditions are stable, supporting more reliable forecasts. Your current mandi (Test Mandi) offers the best available net price. Recommendation: Sell today to secure the current price.
#
# ==================================================
# Scenario: C. Approximately stable price
# Current price: 3000.0
# Forecast price: 3000.0
# Expected percentage change: 0.0%
# Uncertainty: HIGH (Regime: LOW_VOLATILITY)
# Market comparison: Best = Test Mandi @ ₹NOT_AVAILABLE net
# Final recommendation: SELL TODAY
# Reason: Price is expected to remain approximately stable (change of +0.0%, within the ±0.8% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Your current mandi (Test Mandi) offers the best available net price. Recommendation: Sell today to secure the current price.
#
# ==================================================
# Scenario: D. Better alternative mandi
# Current price: 3000.0
# Forecast price: 3000.0
# Expected percentage change: 0.0%
# Uncertainty: HIGH (Regime: LOW_VOLATILITY)
# Market comparison: Best = [TEST_MOCK] Better Mandi @ ₹3300.0 net
# Final recommendation: SELL TODAY
# Reason: Price is expected to remain approximately stable (change of +0.0%, within the ±0.8% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi '[TEST_MOCK] Better Mandi' offers a higher estimated net price of ₹3300/quintal after transport costs. Recommendation: Sell today to secure the current price. Data note: Better net price available at [TEST_MOCK] Better Mandi.
# Warnings: ['Better net price available at [TEST_MOCK] Better Mandi.']
#
# ==================================================
# Scenario: E. High uncertainty overriding point forecast
# Current price: 3000.0
# Forecast price: 3300.0
# Expected percentage change: 10.0%
# Uncertainty: LOW (Regime: HIGH_VOLATILITY)
# Market comparison: Best = Test Mandi @ ₹NOT_AVAILABLE net
# Final recommendation: SELL TODAY
# Reason: Price is expected to remain approximately stable (change of +10.0%, within the ±16.7% uncertainty band). The market is currently in a high-volatility state, making price forecasts less reliable. Your current mandi (Test Mandi) offers the best available net price. Recommendation: Sell today to secure the current price.
#
# ==================================================
# RUNNING ORIGINAL END-TO-END TESTS (WITH MOCK PREFIXES)
# ==================================================
# Original tests:
# Passed: 17
# Failed: 0
#
# Decision-engine scenarios:
# SELL TODAY: 6
# WAIT: 1
# Other: 0
#
# Insufficient-history test:
# PASS
#
# Mock-data isolation:
# PASS
#
# Final verdict:
# READY

# %%
df = pd.read_csv(BASE_DIR / 'outputs' / 'final' / 'decision_engine_validation.csv')
display(df)
# Out:
#                                         Scenario  Current Price  \
# 0        1. Insufficient History (Fallback test)         2500.0
# 1                         2. Mock Data Isolation         2500.0
# 2              A. Strong expected price increase         3000.0
# 3              B. Strong expected price decrease         3400.0
# 4                  C. Approximately stable price         3000.0
# 5                    D. Better alternative mandi         3000.0
# 6  E. High uncertainty overriding point forecast         3000.0
#
#    Forecast Price  Expected Change % Confidence Recommendation  \
# 0          2500.0               0.00     MEDIUM     SELL TODAY
# 1          2500.0               0.00     MEDIUM     SELL TODAY
# 2          3400.0              13.33       HIGH           WAIT
# 3          3000.0             -11.76       HIGH     SELL TODAY
# 4          3000.0               0.00       HIGH     SELL TODAY
# 5          3000.0               0.00       HIGH     SELL TODAY
# 6          3300.0              10.00        LOW     SELL TODAY
#
#                                               Reason
# 0  Price is expected to remain approximately stab...
# 1  Price is expected to remain approximately stab...
# 2  Price is expected to rise by approximately ₹40...
# 3  Price is expected to fall by approximately ₹40...
# 4  Price is expected to remain approximately stab...
# 5  Price is expected to remain approximately stab...
# 6  Price is expected to remain approximately stab...

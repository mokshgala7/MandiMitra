# %% [markdown]
# # Step 17: End-to-End System Test
#
# Run a comprehensive inference test for all 4 crops and edge cases.

# %%
import sys
from pathlib import Path
import pandas as pd
BASE_DIR = Path('..').resolve()
if str(BASE_DIR) not in sys.path: sys.path.insert(0, str(BASE_DIR))

from src.end_to_end_test import main
main()
# Out:
# MANDIMITRA END-TO-END SYSTEM TEST
#
# ==================================================
# Test Case: Rice Valid Case 1
# Crop: rice
# Market: APMC Alibagh
# Current Price: 2600.0
# Forecast Method: persistence
# Forecast Price: 2600.0
# Expected/Actual Future Price: 2600.0
# Forecast Error: 0.0
# Direction: STABLE
# Uncertainty: LOW (Band: 2367.87 to 2832.13)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 2630.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±8.9% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹2630/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Rice Valid Case 2
# Crop: rice
# Market: APMC Murud
# Current Price: 4250.0
# Forecast Method: persistence
# Forecast Price: 4250.0
# Expected/Actual Future Price: 4250.0
# Forecast Error: 0.0
# Direction: STABLE
# Uncertainty: LOW (Band: 3901.8 to 4598.19)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 4280.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±5.5% uncertainty band). The market is currently in a high-volatility state, making price forecasts less reliable. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹4280/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Rice Valid Case 3
# Crop: rice
# Market: APMC Palghar
# Current Price: 4500.0
# Forecast Method: persistence
# Forecast Price: 4500.0
# Expected/Actual Future Price: 4600.0
# Forecast Error: -100.0
# Direction: STABLE
# Uncertainty: LOW (Band: 4151.81 to 4848.19)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 4530.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±5.2% uncertainty band). The market is currently in a high-volatility state, making price forecasts less reliable. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹4530/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Tomato Valid Case 1
# Crop: tomato
# Market: APMC Kamthi
# Current Price: 2770.0
# Forecast Method: persistence
# Forecast Price: 2770.0
# Expected/Actual Future Price: 3310.0
# Forecast Error: -540.0
# Direction: STABLE
# Uncertainty: LOW (Band: 2118.46 to 3421.54)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 2800.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±15.7% uncertainty band). The market is currently in a high-volatility state, making price forecasts less reliable. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹2800/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Tomato Valid Case 2
# Crop: tomato
# Market: Pune(Manjri)
# Current Price: 3000.0
# Forecast Method: persistence
# Forecast Price: 3000.0
# Expected/Actual Future Price: 3000.0
# Forecast Error: 0.0
# Direction: STABLE
# Uncertainty: LOW (Band: 2348.46 to 3651.54)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 3030.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±14.5% uncertainty band). The market is currently in a high-volatility state, making price forecasts less reliable. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹3030/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Tomato Valid Case 3
# Crop: tomato
# Market: APMC Panvel
# Current Price: 2750.0
# Forecast Method: persistence
# Forecast Price: 2750.0
# Expected/Actual Future Price: 3500.0
# Forecast Error: -750.0
# Direction: STABLE
# Uncertainty: LOW (Band: 2098.46 to 3401.54)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 2780.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±15.8% uncertainty band). The market is currently in a high-volatility state, making price forecasts less reliable. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹2780/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Wheat Valid Case 1
# Crop: wheat
# Market: Shevgaon(Bodhegaon)
# Current Price: 2500.0
# Forecast Method: persistence
# Forecast Price: 2500.0
# Expected/Actual Future Price: 2500.0
# Forecast Error: 0.0
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 2431.76 to 2568.24)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 2530.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±2.7% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹2530/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Wheat Valid Case 2
# Crop: wheat
# Market: APMC Jalana
# Current Price: 2600.0
# Forecast Method: persistence
# Forecast Price: 2600.0
# Expected/Actual Future Price: 2600.0
# Forecast Error: 0.0
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 2531.76 to 2668.24)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 2630.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±2.6% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹2630/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Wheat Valid Case 3
# Crop: wheat
# Market: APMC Malkapur
# Current Price: 2650.0
# Forecast Method: persistence
# Forecast Price: 2650.0
# Expected/Actual Future Price: 2700.0
# Forecast Error: -50.0
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 2581.76 to 2718.24)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 2680.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±2.6% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹2680/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Cotton Valid Case 1
# Crop: cotton
# Market: APMC Hinganghat
# Current Price: 7900.0
# Forecast Method: persistence
# Forecast Price: 7900.0
# Expected/Actual Future Price: 7790.0
# Forecast Error: 110.0
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 7687.77 to 8112.23)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 7930.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±2.7% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹7930/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Cotton Valid Case 2
# Crop: cotton
# Market: APMC Hinganghat
# Current Price: 8000.0
# Forecast Method: persistence
# Forecast Price: 8000.0
# Expected/Actual Future Price: 8100.0
# Forecast Error: -100.0
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 7787.77 to 8212.23)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 8030.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±2.7% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹8030/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Cotton Valid Case 3
# Crop: cotton
# Market: APMC Hinganghat
# Current Price: 8200.0
# Forecast Method: persistence
# Forecast Price: 8200.0
# Expected/Actual Future Price: 8000.0
# Forecast Error: 200.0
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 7987.77 to 8412.23)
# Best Alternative Market: Nearby A
# Current Net Price: 0.0 TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: 8230.0
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±2.6% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Nearby mandi 'Nearby A' offers a higher estimated net price of ₹8230/quintal after transport costs. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price. Data note: Better net price available at Nearby A.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Edge Case: Unknown Crop
# Crop: invalid_crop
# Market: Some Market
# Current Price: 1000
# Forecast Method: N/A
# Forecast Price: N/A
# Expected/Actual Future Price: N/A
# Forecast Error: N/A
# Direction: N/A
# Uncertainty: N/A (Band: None to None)
# Best Alternative Market: N/A
# Current Net Price: N/A TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: N/A
# Recommendation: N/A
# Explanation: Caught expected error: Unsupported crop: 'invalid_crop'. Supported: ['rice', 'tomato', 'wheat', 'cotton']
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Edge Case: Unknown Market
# Crop: wheat
# Market: Unknown APMC
# Current Price: 2500
# Forecast Method: persistence
# Forecast Price: 2500.0
# Expected/Actual Future Price: N/A
# Forecast Error: N/A
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 2431.76 to 2568.24)
# Best Alternative Market: Unknown APMC
# Current Net Price: NOT_AVAILABLE TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: NOT_AVAILABLE
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±2.7% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Your current mandi (Unknown APMC) offers the best available net price. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Edge Case: Missing Optional Data (Weather/Transport/Supply)
# Crop: tomato
# Market: APMC Pune
# Current Price: 3000
# Forecast Method: persistence
# Forecast Price: 3000.0
# Expected/Actual Future Price: N/A
# Forecast Error: N/A
# Direction: STABLE
# Uncertainty: LOW (Band: 2565.64 to 3434.36)
# Best Alternative Market: APMC Pune
# Current Net Price: NOT_AVAILABLE TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: NOT_AVAILABLE
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±14.5% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Your current mandi (APMC Pune) offers the best available net price. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Edge Case: Insufficient historical observations
# Crop: rice
# Market: APMC Alibagh
# Current Price: 3500
# Forecast Method: persistence
# Forecast Price: 3500.0
# Expected/Actual Future Price: N/A
# Forecast Error: N/A
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 3267.87 to 3732.13)
# Best Alternative Market: APMC Alibagh
# Current Net Price: NOT_AVAILABLE TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: NOT_AVAILABLE
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±6.6% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Your current mandi (APMC Alibagh) offers the best available net price. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price.
# PASS/FAIL: PASS
#
# ==================================================
# Test Case: Edge Case: Latest Available Date (Cotton)
# Crop: cotton
# Market: APMC Hinganghat
# Current Price: 8000.0
# Forecast Method: persistence
# Forecast Price: 8000.0
# Expected/Actual Future Price: N/A
# Forecast Error: N/A
# Direction: STABLE
# Uncertainty: MEDIUM (Band: 7787.77 to 8212.23)
# Best Alternative Market: APMC Hinganghat
# Current Net Price: NOT_AVAILABLE TC -> Net N/A (home_net implicitly handled if no tc diff)
# Alternative Net Price: NOT_AVAILABLE
# Recommendation: SELL TODAY
# Explanation: Price is expected to remain approximately stable (change of +0.0%, within the ±2.7% uncertainty band). Market conditions are stable, supporting more reliable forecasts. Your current mandi (APMC Hinganghat) offers the best available net price. Forecast is based on persistence (current price as best estimate of near-term price). Recommendation: Sell today to secure the current price.
# PASS/FAIL: PASS
#
# ==================================================
# FINAL TEST REPORT
# ==================================================
# Total tests: 17
# Passed: 17
# Failed: 0
# Warnings: 12
#
# Verdict: READY WITH WARNINGS

# %%
df = pd.read_csv(BASE_DIR / 'outputs' / 'final' / 'end_to_end_test_results.csv')
display(df)
# Out:
#                                                  Case          Crop  \
# 0                                   Rice Valid Case 1          rice
# 1                                   Rice Valid Case 2          rice
# 2                                   Rice Valid Case 3          rice
# 3                                 Tomato Valid Case 1        tomato
# 4                                 Tomato Valid Case 2        tomato
# 5                                 Tomato Valid Case 3        tomato
# 6                                  Wheat Valid Case 1         wheat
# 7                                  Wheat Valid Case 2         wheat
# 8                                  Wheat Valid Case 3         wheat
# 9                                 Cotton Valid Case 1        cotton
# 10                                Cotton Valid Case 2        cotton
# 11                                Cotton Valid Case 3        cotton
# 12                            Edge Case: Unknown Crop  invalid_crop
# 13                          Edge Case: Unknown Market         wheat
# 14  Edge Case: Missing Optional Data (Weather/Tran...        tomato
# 15    Edge Case: Insufficient historical observations          rice
# 16          Edge Case: Latest Available Date (Cotton)        cotton
#
#                  Market  Current Price Forecast Method  Predicted Price  \
# 0          APMC Alibagh         2600.0     persistence           2600.0
# 1            APMC Murud         4250.0     persistence           4250.0
# 2          APMC Palghar         4500.0     persistence           4500.0
# 3           APMC Kamthi         2770.0     persistence           2770.0
# 4          Pune(Manjri)         3000.0     persistence           3000.0
# 5           APMC Panvel         2750.0     persistence           2750.0
# 6   Shevgaon(Bodhegaon)         2500.0     persistence           2500.0
# 7           APMC Jalana         2600.0     persistence           2600.0
# 8         APMC Malkapur         2650.0     persistence           2650.0
# 9       APMC Hinganghat         7900.0     persistence           7900.0
# 10      APMC Hinganghat         8000.0     persistence           8000.0
# 11      APMC Hinganghat         8200.0     persistence           8200.0
# 12          Some Market         1000.0             NaN              NaN
# 13         Unknown APMC         2500.0     persistence           2500.0
# 14            APMC Pune         3000.0     persistence           3000.0
# 15         APMC Alibagh         3500.0     persistence           3500.0
# 16      APMC Hinganghat         8000.0     persistence           8000.0
#
#    Recommendation Pass/Fail  Error Reason
# 0      SELL TODAY      PASS           NaN
# 1      SELL TODAY      PASS           NaN
# 2      SELL TODAY      PASS           NaN
# 3      SELL TODAY      PASS           NaN
# 4      SELL TODAY      PASS           NaN
# 5      SELL TODAY      PASS           NaN
# 6      SELL TODAY      PASS           NaN
# 7      SELL TODAY      PASS           NaN
# 8      SELL TODAY      PASS           NaN
# 9      SELL TODAY      PASS           NaN
# 10     SELL TODAY      PASS           NaN
# 11     SELL TODAY      PASS           NaN
# 12            NaN      PASS           NaN
# 13     SELL TODAY      PASS           NaN
# 14     SELL TODAY      PASS           NaN
# 15     SELL TODAY      PASS           NaN
# 16     SELL TODAY      PASS           NaN
